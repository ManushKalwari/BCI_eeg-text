# %%
import sys
import os

# Get absolute path to your project root (one level above eeg_pretraining)
project_root = os.path.abspath(os.path.join(os.getcwd()))
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

from eeg_pretraining.pretrainer_model import EEGPretrainer
from eeg_text_dataset import EEGTextDataset, collate_fn

# %%
# === Config ===
batch_size = 16
epochs = 20
lr = 1e-4
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# === Data ===
dataset = EEGTextDataset("BCI_trainingData/")
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)

# === Model ===
model = EEGPretrainer().to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)
criterion = nn.MSELoss()
# Out:
# [resultsYDG_NR_pairs.mat] Index 0: word = 'ford', eeg shape = (105, 98)
# [resultsYDG_NR_pairs.mat] Index 1: word = 'edsel', eeg shape = (105, 140)
# [resultsYDG_NR_pairs.mat] Index 2: word = 'founded', eeg shape = (105, 94)
# [resultsYDG_NR_pairs.mat] Index 3: word = 'foundation', eeg shape = (105, 77)
# [resultsYDG_NR_pairs.mat] Index 4: word = '1936', eeg shape = (105, 169)
# [resultsYDG_NR_pairs.mat] Index 5: word = 'a', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 6: word = 'local', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 7: word = 'philanthropic', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 8: word = 'organization', eeg shape = (105, 151)
# [resultsYDG_NR_pairs.mat] Index 9: word = 'broad', eeg shape = (105, 158)
# [resultsYDG_NR_pairs.mat] Index 10: word = 'charter', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 11: word = 'to', eeg shape = (105, 111)
# [resultsYDG_NR_pairs.mat] Index 12: word = 'promote', eeg shape = (105, 109)
# [resultsYDG_NR_pairs.mat] Index 13: word = 'human', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 14: word = 'this', eeg shape = (105, 68)
# [resultsYDG_NR_pairs.mat] Index 15: word = 'initial', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 16: word = 'edison', eeg shape = (105, 136)
# [resultsYDG_NR_pairs.mat] Index 17: word = 'illuminating', eeg shape = (105, 194)
# [resultsYDG_NR_pairs.mat] Index 18: word = 'other', eeg shape = (105, 118)
# [resultsYDG_NR_pairs.mat] Index 19: word = 'investors', eeg shape = (105, 77)
# [resultsYDG_NR_pairs.mat] Index 20: word = 'formed', eeg shape = (105, 146)
# [resultsYDG_NR_pairs.mat] Index 21: word = 'the', eeg shape = (105, 100)
# [resultsYDG_NR_pairs.mat] Index 22: word = 'automobile', eeg shape = (105, 153)
# [resultsYDG_NR_pairs.mat] Index 23: word = 'his', eeg shape = (105, 71)
# [resultsYDG_NR_pairs.mat] Index 24: word = 'interest', eeg shape = (105, 124)
# [resultsYDG_NR_pairs.mat] Index 25: word = 'he', eeg shape = (105, 119)
# [resultsYDG_NR_pairs.mat] Index 26: word = 'second', eeg shape = (105, 148)
# [resultsYDG_NR_pairs.mat] Index 27: word = 'company', eeg shape = (105, 120)
# [resultsYDG_NR_pairs.mat] Index 28: word = 'henry', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 29: word = 'ford', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 30: word = 'company', eeg shape = (105, 62)
# [resultsYDG_NR_pairs.mat] Index 31: word = 'this', eeg shape = (105, 100)
# [resultsYDG_NR_pairs.mat] Index 32: word = 'period', eeg shape = (105, 55)
# [resultsYDG_NR_pairs.mat] Index 33: word = 'personally', eeg shape = (105, 137)
# [resultsYDG_NR_pairs.mat] Index 34: word = 'drove', eeg shape = (105, 83)
# [resultsYDG_NR_pairs.mat] Index 35: word = 'quadricycle', eeg shape = (105, 218)
# [resultsYDG_NR_pairs.mat] Index 36: word = 'victory', eeg shape = (105, 90)
# [resultsYDG_NR_pairs.mat] Index 37: word = 'in', eeg shape = (105, 98)
# [resultsYDG_NR_pairs.mat] Index 38: word = 'a', eeg shape = (105, 110)
# [resultsYDG_NR_pairs.mat] Index 39: word = 'race', eeg shape = (105, 55)
# [resultsYDG_NR_pairs.mat] Index 40: word = 'against', eeg shape = (105, 107)
# [resultsYDG_NR_pairs.mat] Index 41: word = 'winton', eeg shape = (105, 131)
# [resultsYDG_NR_pairs.mat] Index 42: word = 'a', eeg shape = (105, 70)
# [resultsYDG_NR_pairs.mat] Index 43: word = 'wellknown', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 44: word = 'driver', eeg shape = (105, 182)
# [resultsYDG_NR_pairs.mat] Index 45: word = 'the', eeg shape = (105, 173)
# [resultsYDG_NR_pairs.mat] Index 46: word = 'heavy', eeg shape = (105, 136)
# [resultsYDG_NR_pairs.mat] Index 47: word = 'favorite', eeg shape = (105, 113)
# [resultsYDG_NR_pairs.mat] Index 48: word = 'on', eeg shape = (105, 55)
# [resultsYDG_NR_pairs.mat] Index 49: word = 'october', eeg shape = (105, 185)
# [resultsYDG_NR_pairs.mat] Index 50: word = '1901', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 51: word = 'was', eeg shape = (105, 82)
# [resultsYDG_NR_pairs.mat] Index 52: word = 'forced', eeg shape = (105, 124)
# [resultsYDG_NR_pairs.mat] Index 53: word = 'of', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 54: word = 'company', eeg shape = (105, 104)
# [resultsYDG_NR_pairs.mat] Index 55: word = 'by', eeg shape = (105, 104)
# [resultsYDG_NR_pairs.mat] Index 56: word = 'investors', eeg shape = (105, 80)
# [resultsYDG_NR_pairs.mat] Index 57: word = 'including', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 58: word = 'henry', eeg shape = (105, 96)
# [resultsYDG_NR_pairs.mat] Index 59: word = 'leland', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 60: word = 'in', eeg shape = (105, 114)
# [resultsYDG_NR_pairs.mat] Index 61: word = '1902', eeg shape = (105, 89)
# [resultsYDG_NR_pairs.mat] Index 62: word = 'the', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 63: word = 'company', eeg shape = (105, 157)
# [resultsYDG_NR_pairs.mat] Index 64: word = 'reorganized', eeg shape = (105, 153)
# [resultsYDG_NR_pairs.mat] Index 65: word = 'cadillac', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 66: word = '1891', eeg shape = (105, 161)
# [resultsYDG_NR_pairs.mat] Index 67: word = 'became', eeg shape = (105, 70)
# [resultsYDG_NR_pairs.mat] Index 68: word = 'engineer', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 69: word = 'the', eeg shape = (105, 69)
# [resultsYDG_NR_pairs.mat] Index 70: word = 'edison', eeg shape = (105, 87)
# [resultsYDG_NR_pairs.mat] Index 71: word = 'illuminating', eeg shape = (105, 225)
# [resultsYDG_NR_pairs.mat] Index 72: word = 'company', eeg shape = (105, 70)
# [resultsYDG_NR_pairs.mat] Index 73: word = 'and', eeg shape = (105, 92)
# [resultsYDG_NR_pairs.mat] Index 74: word = 'after', eeg shape = (105, 98)
# [resultsYDG_NR_pairs.mat] Index 75: word = 'promotion', eeg shape = (105, 141)
# [resultsYDG_NR_pairs.mat] Index 76: word = 'chief', eeg shape = (105, 101)
# [resultsYDG_NR_pairs.mat] Index 77: word = 'engineer', eeg shape = (105, 135)
# [resultsYDG_NR_pairs.mat] Index 78: word = '1893', eeg shape = (105, 271)
# [resultsYDG_NR_pairs.mat] Index 79: word = 'had', eeg shape = (105, 73)
# [resultsYDG_NR_pairs.mat] Index 80: word = 'enough', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 81: word = 'money', eeg shape = (105, 97)
# [resultsYDG_NR_pairs.mat] Index 82: word = 'devote', eeg shape = (105, 144)
# [resultsYDG_NR_pairs.mat] Index 83: word = 'attention', eeg shape = (105, 105)
# [resultsYDG_NR_pairs.mat] Index 84: word = 'to', eeg shape = (105, 88)
# [resultsYDG_NR_pairs.mat] Index 85: word = 'personal', eeg shape = (105, 119)
# [resultsYDG_NR_pairs.mat] Index 86: word = 'experiments', eeg shape = (105, 140)
# [resultsYDG_NR_pairs.mat] Index 87: word = 'internal', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 88: word = 'combustion', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 89: word = 'culminated', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 90: word = 'in', eeg shape = (105, 89)
# [resultsYDG_NR_pairs.mat] Index 91: word = '1896', eeg shape = (105, 88)
# [resultsYDG_NR_pairs.mat] Index 92: word = 'completion', eeg shape = (105, 178)
# [resultsYDG_NR_pairs.mat] Index 93: word = 'own', eeg shape = (105, 88)
# [resultsYDG_NR_pairs.mat] Index 94: word = 'selfpropelled', eeg shape = (105, 100)
# [resultsYDG_NR_pairs.mat] Index 95: word = 'vehicle', eeg shape = (105, 53)
# [resultsYDG_NR_pairs.mat] Index 96: word = 'named', eeg shape = (105, 104)
# [resultsYDG_NR_pairs.mat] Index 97: word = 'quadricycle', eeg shape = (105, 114)
# [resultsYDG_NR_pairs.mat] Index 98: word = 'which', eeg shape = (105, 75)
# [resultsYDG_NR_pairs.mat] Index 99: word = 'testdrove', eeg shape = (105, 142)
# [resultsYDG_NR_pairs.mat] Index 100: word = 'june', eeg shape = (105, 98)
# [resultsYDG_NR_pairs.mat] Index 101: word = '4', eeg shape = (105, 94)
# [resultsYDG_NR_pairs.mat] Index 102: word = 'of', eeg shape = (105, 141)
# [resultsYDG_NR_pairs.mat] Index 103: word = 'that', eeg shape = (105, 70)
# [resultsYDG_NR_pairs.mat] Index 104: word = 'was', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 105: word = 'born', eeg shape = (105, 132)
# [resultsYDG_NR_pairs.mat] Index 106: word = 'on', eeg shape = (105, 80)
# [resultsYDG_NR_pairs.mat] Index 107: word = 'a', eeg shape = (105, 174)
# [resultsYDG_NR_pairs.mat] Index 108: word = 'prosperous', eeg shape = (105, 105)
# [resultsYDG_NR_pairs.mat] Index 109: word = 'farm', eeg shape = (105, 180)
# [resultsYDG_NR_pairs.mat] Index 110: word = 'springwells', eeg shape = (105, 71)
# [resultsYDG_NR_pairs.mat] Index 111: word = 'township', eeg shape = (105, 180)
# [resultsYDG_NR_pairs.mat] Index 112: word = 'now', eeg shape = (105, 131)
# [resultsYDG_NR_pairs.mat] Index 113: word = 'the', eeg shape = (105, 203)
# [resultsYDG_NR_pairs.mat] Index 114: word = 'city', eeg shape = (105, 166)
# [resultsYDG_NR_pairs.mat] Index 115: word = 'dearborn', eeg shape = (105, 109)
# [resultsYDG_NR_pairs.mat] Index 116: word = 'michigan', eeg shape = (105, 74)
# [resultsYDG_NR_pairs.mat] Index 117: word = 'owned', eeg shape = (105, 82)
# [resultsYDG_NR_pairs.mat] Index 118: word = 'parents', eeg shape = (105, 82)
# [resultsYDG_NR_pairs.mat] Index 119: word = 'william', eeg shape = (105, 83)
# [resultsYDG_NR_pairs.mat] Index 120: word = 'ford', eeg shape = (105, 117)
# [resultsYDG_NR_pairs.mat] Index 121: word = '18261905', eeg shape = (105, 147)
# [resultsYDG_NR_pairs.mat] Index 122: word = 'and', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 123: word = 'mary', eeg shape = (105, 128)
# [resultsYDG_NR_pairs.mat] Index 124: word = 'litogot', eeg shape = (105, 102)
# [resultsYDG_NR_pairs.mat] Index 125: word = 'c18391876', eeg shape = (105, 191)
# [resultsYDG_NR_pairs.mat] Index 126: word = 'immigrants', eeg shape = (105, 172)
# [resultsYDG_NR_pairs.mat] Index 127: word = 'county', eeg shape = (105, 51)
# [resultsYDG_NR_pairs.mat] Index 128: word = 'cork', eeg shape = (105, 160)
# [resultsYDG_NR_pairs.mat] Index 129: word = 'the', eeg shape = (105, 54)
# [resultsYDG_NR_pairs.mat] Index 130: word = 'years', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 131: word = 'between', eeg shape = (105, 165)
# [resultsYDG_NR_pairs.mat] Index 132: word = 'wars', eeg shape = (105, 123)
# [resultsYDG_NR_pairs.mat] Index 133: word = 'ford', eeg shape = (105, 143)
# [resultsYDG_NR_pairs.mat] Index 134: word = 'supported', eeg shape = (105, 121)
# [resultsYDG_NR_pairs.mat] Index 135: word = 'hitlers', eeg shape = (105, 111)
# [resultsYDG_NR_pairs.mat] Index 136: word = 'nazi', eeg shape = (105, 62)
# [resultsYDG_NR_pairs.mat] Index 137: word = 'regime', eeg shape = (105, 82)
# [resultsYDG_NR_pairs.mat] Index 138: word = 'is', eeg shape = (105, 77)
# [resultsYDG_NR_pairs.mat] Index 139: word = 'also', eeg shape = (105, 124)
# [resultsYDG_NR_pairs.mat] Index 140: word = 'some', eeg shape = (105, 175)
# [resultsYDG_NR_pairs.mat] Index 141: word = 'evidence', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 142: word = 'henry', eeg shape = (105, 139)
# [resultsYDG_NR_pairs.mat] Index 143: word = 'gave', eeg shape = (105, 143)
# [resultsYDG_NR_pairs.mat] Index 144: word = 'adolf', eeg shape = (105, 52)
# [resultsYDG_NR_pairs.mat] Index 145: word = 'direct', eeg shape = (105, 93)
# [resultsYDG_NR_pairs.mat] Index 146: word = 'financial', eeg shape = (105, 68)
# [resultsYDG_NR_pairs.mat] Index 147: word = 'when', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 148: word = 'hitler', eeg shape = (105, 66)
# [resultsYDG_NR_pairs.mat] Index 149: word = 'first', eeg shape = (105, 70)
# [resultsYDG_NR_pairs.mat] Index 150: word = 'starting', eeg shape = (105, 57)
# [resultsYDG_NR_pairs.mat] Index 151: word = 'out', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 152: word = 'politics', eeg shape = (105, 149)
# [resultsYDG_NR_pairs.mat] Index 153: word = 'can', eeg shape = (105, 117)
# [resultsYDG_NR_pairs.mat] Index 154: word = 'part', eeg shape = (105, 100)
# [resultsYDG_NR_pairs.mat] Index 155: word = 'traced', eeg shape = (105, 79)
# [resultsYDG_NR_pairs.mat] Index 156: word = 'statements', eeg shape = (105, 145)
# [resultsYDG_NR_pairs.mat] Index 157: word = 'from', eeg shape = (105, 79)
# [resultsYDG_NR_pairs.mat] Index 158: word = 'kurt', eeg shape = (105, 93)
# [resultsYDG_NR_pairs.mat] Index 159: word = 'ludecke', eeg shape = (105, 102)
# [resultsYDG_NR_pairs.mat] Index 160: word = 'germanys', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 161: word = 'representative', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 162: word = 'the', eeg shape = (105, 107)
# [resultsYDG_NR_pairs.mat] Index 163: word = 'us', eeg shape = (105, 65)
# [resultsYDG_NR_pairs.mat] Index 164: word = '1920s', eeg shape = (105, 143)
# [resultsYDG_NR_pairs.mat] Index 165: word = 'winifred', eeg shape = (105, 125)
# [resultsYDG_NR_pairs.mat] Index 166: word = 'wagner', eeg shape = (105, 82)
# [resultsYDG_NR_pairs.mat] Index 167: word = 'daughterinlaw', eeg shape = (105, 123)
# [resultsYDG_NR_pairs.mat] Index 168: word = 'richard', eeg shape = (105, 143)
# [resultsYDG_NR_pairs.mat] Index 169: word = 'wagner', eeg shape = (105, 81)
# [resultsYDG_NR_pairs.mat] Index 170: word = 'said', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 171: word = 'they', eeg shape = (105, 90)
# [resultsYDG_NR_pairs.mat] Index 172: word = 'requested', eeg shape = (105, 144)
# [resultsYDG_NR_pairs.mat] Index 173: word = 'funds', eeg shape = (105, 73)
# [resultsYDG_NR_pairs.mat] Index 174: word = 'ford', eeg shape = (105, 127)
# [resultsYDG_NR_pairs.mat] Index 175: word = 'aid', eeg shape = (105, 86)
# [resultsYDG_NR_pairs.mat] Index 176: word = 'national', eeg shape = (105, 110)
# [resultsYDG_NR_pairs.mat] Index 177: word = 'socialist', eeg shape = (105, 130)
# [resultsYDG_NR_pairs.mat] Index 178: word = 'ford', eeg shape = (105, 117)
# [resultsYDG_NR_pairs.mat] Index 179: word = 'often', eeg shape = (105, 89)
# [resultsYDG_NR_pairs.mat] Index 180: word = 'credited', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 181: word = 'with', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 182: word = 'the', eeg shape = (105, 82)
# [resultsYDG_NR_pairs.mat] Index 183: word = 'idea', eeg shape = (105, 121)
# [resultsYDG_NR_pairs.mat] Index 184: word = 'contemporary', eeg shape = (105, 52)
# [resultsYDG_NR_pairs.mat] Index 185: word = 'sources', eeg shape = (105, 124)
# [resultsYDG_NR_pairs.mat] Index 186: word = 'indicate', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 187: word = 'the', eeg shape = (105, 211)
# [resultsYDG_NR_pairs.mat] Index 188: word = 'concept', eeg shape = (105, 141)
# [resultsYDG_NR_pairs.mat] Index 189: word = 'and', eeg shape = (105, 119)
# [resultsYDG_NR_pairs.mat] Index 190: word = 'its', eeg shape = (105, 77)
# [resultsYDG_NR_pairs.mat] Index 191: word = 'development', eeg shape = (105, 133)
# [resultsYDG_NR_pairs.mat] Index 192: word = 'came', eeg shape = (105, 100)
# [resultsYDG_NR_pairs.mat] Index 193: word = 'from', eeg shape = (105, 119)
# [resultsYDG_NR_pairs.mat] Index 194: word = 'employees', eeg shape = (105, 74)
# [resultsYDG_NR_pairs.mat] Index 195: word = 'clarence', eeg shape = (105, 143)
# [resultsYDG_NR_pairs.mat] Index 196: word = 'avery', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 197: word = 'peter', eeg shape = (105, 71)
# [resultsYDG_NR_pairs.mat] Index 198: word = 'e', eeg shape = (105, 121)
# [resultsYDG_NR_pairs.mat] Index 199: word = 'martin', eeg shape = (105, 155)
# [resultsYDG_NR_pairs.mat] Index 200: word = 'charles', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 201: word = 'sorensen', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 202: word = 'ch', eeg shape = (105, 145)
# [resultsYDG_NR_pairs.mat] Index 203: word = 'wills', eeg shape = (105, 97)
# [resultsYDG_NR_pairs.mat] Index 204: word = 'ford', eeg shape = (105, 67)
# [resultsYDG_NR_pairs.mat] Index 205: word = 'advocated', eeg shape = (105, 134)
# [resultsYDG_NR_pairs.mat] Index 206: word = 'longtime', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 207: word = 'associate', eeg shape = (105, 108)
# [resultsYDG_NR_pairs.mat] Index 208: word = 'harry', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 209: word = 'bennett', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 210: word = 'take', eeg shape = (105, 79)
# [resultsYDG_NR_pairs.mat] Index 211: word = 'the', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 212: word = 'spot', eeg shape = (105, 97)
# [resultsYDG_NR_pairs.mat] Index 213: word = 'edsels', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 214: word = 'widow', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 215: word = 'eleanor', eeg shape = (105, 96)
# [resultsYDG_NR_pairs.mat] Index 216: word = 'had', eeg shape = (105, 104)
# [resultsYDG_NR_pairs.mat] Index 217: word = 'inherited', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 218: word = 'edsels', eeg shape = (105, 72)
# [resultsYDG_NR_pairs.mat] Index 219: word = 'voting', eeg shape = (105, 135)
# [resultsYDG_NR_pairs.mat] Index 220: word = 'stock', eeg shape = (105, 114)
# [resultsYDG_NR_pairs.mat] Index 221: word = 'wanted', eeg shape = (105, 104)
# [resultsYDG_NR_pairs.mat] Index 222: word = 'son', eeg shape = (105, 124)
# [resultsYDG_NR_pairs.mat] Index 223: word = 'ii', eeg shape = (105, 173)
# [resultsYDG_NR_pairs.mat] Index 224: word = 'take', eeg shape = (105, 88)
# [resultsYDG_NR_pairs.mat] Index 225: word = 'over', eeg shape = (105, 90)
# [resultsYDG_NR_pairs.mat] Index 226: word = 'position', eeg shape = (105, 108)
# [resultsYDG_NR_pairs.mat] Index 227: word = 'he', eeg shape = (105, 192)
# [resultsYDG_NR_pairs.mat] Index 228: word = 'left', eeg shape = (105, 62)
# [resultsYDG_NR_pairs.mat] Index 229: word = 'home', eeg shape = (105, 87)
# [resultsYDG_NR_pairs.mat] Index 230: word = 'the', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 231: word = 'nearby', eeg shape = (105, 149)
# [resultsYDG_NR_pairs.mat] Index 232: word = 'city', eeg shape = (105, 79)
# [resultsYDG_NR_pairs.mat] Index 233: word = 'detroit', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 234: word = 'work', eeg shape = (105, 161)
# [resultsYDG_NR_pairs.mat] Index 235: word = 'as', eeg shape = (105, 143)
# [resultsYDG_NR_pairs.mat] Index 236: word = 'an', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 237: word = 'apprentice', eeg shape = (105, 105)
# [resultsYDG_NR_pairs.mat] Index 238: word = 'machinist', eeg shape = (105, 82)
# [resultsYDG_NR_pairs.mat] Index 239: word = 'first', eeg shape = (105, 227)
# [resultsYDG_NR_pairs.mat] Index 240: word = 'james', eeg shape = (105, 200)
# [resultsYDG_NR_pairs.mat] Index 241: word = '', eeg shape = (105, 234)
# [resultsYDG_NR_pairs.mat] Index 242: word = 'bros', eeg shape = (105, 111)
# [resultsYDG_NR_pairs.mat] Index 243: word = 'with', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 244: word = 'the', eeg shape = (105, 91)
# [resultsYDG_NR_pairs.mat] Index 245: word = 'detroit', eeg shape = (105, 96)
# [resultsYDG_NR_pairs.mat] Index 246: word = 'dry', eeg shape = (105, 73)
# [resultsYDG_NR_pairs.mat] Index 247: word = 'dock', eeg shape = (105, 139)
# [resultsYDG_NR_pairs.mat] Index 248: word = 'alexander', eeg shape = (105, 117)
# [resultsYDG_NR_pairs.mat] Index 249: word = 'rae', eeg shape = (105, 213)
# [resultsYDG_NR_pairs.mat] Index 250: word = 'baldwin', eeg shape = (105, 118)
# [resultsYDG_NR_pairs.mat] Index 251: word = 'born', eeg shape = (105, 67)
# [resultsYDG_NR_pairs.mat] Index 252: word = 'april', eeg shape = (105, 65)
# [resultsYDG_NR_pairs.mat] Index 253: word = '1958', eeg shape = (105, 204)
# [resultsYDG_NR_pairs.mat] Index 254: word = 'massapequa', eeg shape = (105, 54)
# [resultsYDG_NR_pairs.mat] Index 255: word = 'long', eeg shape = (105, 64)
# [resultsYDG_NR_pairs.mat] Index 256: word = 'island', eeg shape = (105, 59)
# [resultsYDG_NR_pairs.mat] Index 257: word = 'is', eeg shape = (105, 156)
# [resultsYDG_NR_pairs.mat] Index 258: word = 'american', eeg shape = (105, 77)
# [resultsYDG_NR_pairs.mat] Index 259: word = 'is', eeg shape = (105, 135)
# [resultsYDG_NR_pairs.mat] Index 260: word = 'the', eeg shape = (105, 118)
# [resultsYDG_NR_pairs.mat] Index 261: word = 'oldest', eeg shape = (105, 110)
# [resultsYDG_NR_pairs.mat] Index 262: word = 'and', eeg shape = (105, 156)
# [resultsYDG_NR_pairs.mat] Index 263: word = 'known', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 264: word = 'the', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 265: word = 'baldwin', eeg shape = (105, 165)
# [resultsYDG_NR_pairs.mat] Index 266: word = 'brothers', eeg shape = (105, 104)
# [resultsYDG_NR_pairs.mat] Index 267: word = 'brothers', eeg shape = (105, 98)
# [resultsYDG_NR_pairs.mat] Index 268: word = 'daniel', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 269: word = 'stephen', eeg shape = (105, 150)
# [resultsYDG_NR_pairs.mat] Index 270: word = 'and', eeg shape = (105, 127)
# [resultsYDG_NR_pairs.mat] Index 271: word = 'of', eeg shape = (105, 125)
# [resultsYDG_NR_pairs.mat] Index 272: word = 'three', eeg shape = (105, 163)
# [resultsYDG_NR_pairs.mat] Index 273: word = 'quarters', eeg shape = (105, 153)
# [resultsYDG_NR_pairs.mat] Index 274: word = 'and', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 275: word = 'quarter', eeg shape = (105, 131)
# [resultsYDG_NR_pairs.mat] Index 276: word = 'french', eeg shape = (105, 53)
# [resultsYDG_NR_pairs.mat] Index 277: word = 'descent', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 278: word = 'has', eeg shape = (105, 147)
# [resultsYDG_NR_pairs.mat] Index 279: word = 'appeared', eeg shape = (105, 119)
# [resultsYDG_NR_pairs.mat] Index 280: word = 'movies', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 281: word = 'such', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 282: word = 'as', eeg shape = (105, 61)
# [resultsYDG_NR_pairs.mat] Index 283: word = 'cooler', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 284: word = 'the', eeg shape = (105, 96)
# [resultsYDG_NR_pairs.mat] Index 285: word = 'hunt', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 286: word = 'for', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 287: word = 'october', eeg shape = (105, 61)
# [resultsYDG_NR_pairs.mat] Index 288: word = 'beetlejuice', eeg shape = (105, 117)
# [resultsYDG_NR_pairs.mat] Index 289: word = 'ghosts', eeg shape = (105, 77)
# [resultsYDG_NR_pairs.mat] Index 290: word = 'mississippi', eeg shape = (105, 144)
# [resultsYDG_NR_pairs.mat] Index 291: word = 'talk', eeg shape = (105, 98)
# [resultsYDG_NR_pairs.mat] Index 292: word = 'radio', eeg shape = (105, 142)
# [resultsYDG_NR_pairs.mat] Index 293: word = 'final', eeg shape = (105, 138)
# [resultsYDG_NR_pairs.mat] Index 294: word = 'fantasy', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 295: word = 'spirits', eeg shape = (105, 139)
# [resultsYDG_NR_pairs.mat] Index 296: word = 'within', eeg shape = (105, 73)
# [resultsYDG_NR_pairs.mat] Index 297: word = 'voice', eeg shape = (105, 96)
# [resultsYDG_NR_pairs.mat] Index 298: word = 'in', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 299: word = 'hat', eeg shape = (105, 113)
# [resultsYDG_NR_pairs.mat] Index 300: word = 'harbor', eeg shape = (105, 134)
# [resultsYDG_NR_pairs.mat] Index 301: word = 'thomas', eeg shape = (105, 91)
# [resultsYDG_NR_pairs.mat] Index 302: word = 'the', eeg shape = (105, 61)
# [resultsYDG_NR_pairs.mat] Index 303: word = 'railroad', eeg shape = (105, 113)
# [resultsYDG_NR_pairs.mat] Index 304: word = 'along', eeg shape = (105, 123)
# [resultsYDG_NR_pairs.mat] Index 305: word = 'came', eeg shape = (105, 91)
# [resultsYDG_NR_pairs.mat] Index 306: word = 'polly', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 307: word = 'spongebob', eeg shape = (105, 120)
# [resultsYDG_NR_pairs.mat] Index 308: word = 'squarepants', eeg shape = (105, 166)
# [resultsYDG_NR_pairs.mat] Index 309: word = 'movie', eeg shape = (105, 80)
# [resultsYDG_NR_pairs.mat] Index 310: word = 'the', eeg shape = (105, 86)
# [resultsYDG_NR_pairs.mat] Index 311: word = 'aviator', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 312: word = 'young', eeg shape = (105, 144)
# [resultsYDG_NR_pairs.mat] Index 313: word = 'had', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 314: word = 'a', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 315: word = 'as', eeg shape = (105, 143)
# [resultsYDG_NR_pairs.mat] Index 316: word = 'a', eeg shape = (105, 191)
# [resultsYDG_NR_pairs.mat] Index 317: word = 'busboy', eeg shape = (105, 100)
# [resultsYDG_NR_pairs.mat] Index 318: word = 'famous', eeg shape = (105, 86)
# [resultsYDG_NR_pairs.mat] Index 319: word = 'new', eeg shape = (105, 86)
# [resultsYDG_NR_pairs.mat] Index 320: word = 'city', eeg shape = (105, 126)
# [resultsYDG_NR_pairs.mat] Index 321: word = 'disco', eeg shape = (105, 159)
# [resultsYDG_NR_pairs.mat] Index 322: word = '54', eeg shape = (105, 109)
# [resultsYDG_NR_pairs.mat] Index 323: word = 'was', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 324: word = 'to', eeg shape = (105, 75)
# [resultsYDG_NR_pairs.mat] Index 325: word = 'kim', eeg shape = (105, 89)
# [resultsYDG_NR_pairs.mat] Index 326: word = 'basinger', eeg shape = (105, 68)
# [resultsYDG_NR_pairs.mat] Index 327: word = '1993', eeg shape = (105, 209)
# [resultsYDG_NR_pairs.mat] Index 328: word = '2002', eeg shape = (105, 64)
# [resultsYDG_NR_pairs.mat] Index 329: word = 'baldwin', eeg shape = (105, 66)
# [resultsYDG_NR_pairs.mat] Index 330: word = 'a', eeg shape = (105, 88)
# [resultsYDG_NR_pairs.mat] Index 331: word = 'democrat', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 332: word = 'always', eeg shape = (105, 109)
# [resultsYDG_NR_pairs.mat] Index 333: word = 'had', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 334: word = 'active', eeg shape = (105, 98)
# [resultsYDG_NR_pairs.mat] Index 335: word = 'interest', eeg shape = (105, 82)
# [resultsYDG_NR_pairs.mat] Index 336: word = 'politics', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 337: word = 'and', eeg shape = (105, 53)
# [resultsYDG_NR_pairs.mat] Index 338: word = 'frequently', eeg shape = (105, 152)
# [resultsYDG_NR_pairs.mat] Index 339: word = 'rumored', eeg shape = (105, 148)
# [resultsYDG_NR_pairs.mat] Index 340: word = 'candidate', eeg shape = (105, 111)
# [resultsYDG_NR_pairs.mat] Index 341: word = 'for', eeg shape = (105, 79)
# [resultsYDG_NR_pairs.mat] Index 342: word = 'office', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 343: word = 'particular', eeg shape = (105, 60)
# [resultsYDG_NR_pairs.mat] Index 344: word = 'baldwin', eeg shape = (105, 66)
# [resultsYDG_NR_pairs.mat] Index 345: word = 'of', eeg shape = (105, 111)
# [resultsYDG_NR_pairs.mat] Index 346: word = 'frequent', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 347: word = 'of', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 348: word = 'saturday', eeg shape = (105, 101)
# [resultsYDG_NR_pairs.mat] Index 349: word = 'leading', eeg shape = (105, 100)
# [resultsYDG_NR_pairs.mat] Index 350: word = 'show', eeg shape = (105, 66)
# [resultsYDG_NR_pairs.mat] Index 351: word = 'eleven', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 352: word = 'times', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 353: word = 'also', eeg shape = (105, 130)
# [resultsYDG_NR_pairs.mat] Index 354: word = 'making', eeg shape = (105, 102)
# [resultsYDG_NR_pairs.mat] Index 355: word = 'regularly', eeg shape = (105, 72)
# [resultsYDG_NR_pairs.mat] Index 356: word = 'played', eeg shape = (105, 127)
# [resultsYDG_NR_pairs.mat] Index 357: word = 'barrett', eeg shape = (105, 150)
# [resultsYDG_NR_pairs.mat] Index 358: word = 'travis', eeg shape = (105, 206)
# [resultsYDG_NR_pairs.mat] Index 359: word = 'movie', eeg shape = (105, 93)
# [resultsYDG_NR_pairs.mat] Index 360: word = 'about', eeg shape = (105, 132)
# [resultsYDG_NR_pairs.mat] Index 361: word = 'alamo', eeg shape = (105, 153)
# [resultsYDG_NR_pairs.mat] Index 362: word = 'called', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 363: word = 'thirteen', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 364: word = 'days', eeg shape = (105, 109)
# [resultsYDG_NR_pairs.mat] Index 365: word = 'of', eeg shape = (105, 89)
# [resultsYDG_NR_pairs.mat] Index 366: word = '1998', eeg shape = (105, 109)
# [resultsYDG_NR_pairs.mat] Index 367: word = 'began', eeg shape = (105, 123)
# [resultsYDG_NR_pairs.mat] Index 368: word = 'narrating', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 369: word = 'american', eeg shape = (105, 82)
# [resultsYDG_NR_pairs.mat] Index 370: word = 'version', eeg shape = (105, 70)
# [resultsYDG_NR_pairs.mat] Index 371: word = 'childrens', eeg shape = (105, 120)
# [resultsYDG_NR_pairs.mat] Index 372: word = 'thomas', eeg shape = (105, 108)
# [resultsYDG_NR_pairs.mat] Index 373: word = 'engine', eeg shape = (105, 93)
# [resultsYDG_NR_pairs.mat] Index 374: word = 'and', eeg shape = (105, 64)
# [resultsYDG_NR_pairs.mat] Index 375: word = 'friends', eeg shape = (105, 137)
# [resultsYDG_NR_pairs.mat] Index 376: word = 'infamous', eeg shape = (105, 93)
# [resultsYDG_NR_pairs.mat] Index 377: word = 'his', eeg shape = (105, 81)
# [resultsYDG_NR_pairs.mat] Index 378: word = '1994', eeg shape = (105, 65)
# [resultsYDG_NR_pairs.mat] Index 379: word = 'appearance', eeg shape = (105, 87)
# [resultsYDG_NR_pairs.mat] Index 380: word = 'saturday', eeg shape = (105, 110)
# [resultsYDG_NR_pairs.mat] Index 381: word = 'live', eeg shape = (105, 102)
# [resultsYDG_NR_pairs.mat] Index 382: word = 'potrays', eeg shape = (105, 92)
# [resultsYDG_NR_pairs.mat] Index 383: word = 'mr', eeg shape = (105, 111)
# [resultsYDG_NR_pairs.mat] Index 384: word = 'armstrong', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 385: word = 'scoutmaster', eeg shape = (105, 121)
# [resultsYDG_NR_pairs.mat] Index 386: word = 'a', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 387: word = 'pedophile', eeg shape = (105, 132)
# [resultsYDG_NR_pairs.mat] Index 388: word = 'rips', eeg shape = (105, 110)
# [resultsYDG_NR_pairs.mat] Index 389: word = 'shirt', eeg shape = (105, 105)
# [resultsYDG_NR_pairs.mat] Index 390: word = 'and', eeg shape = (105, 110)
# [resultsYDG_NR_pairs.mat] Index 391: word = 'puts', eeg shape = (105, 105)
# [resultsYDG_NR_pairs.mat] Index 392: word = 'around', eeg shape = (105, 135)
# [resultsYDG_NR_pairs.mat] Index 393: word = 'adam', eeg shape = (105, 61)
# [resultsYDG_NR_pairs.mat] Index 394: word = 'sandlers', eeg shape = (105, 116)
# [resultsYDG_NR_pairs.mat] Index 395: word = 'neck', eeg shape = (105, 57)
# [resultsYDG_NR_pairs.mat] Index 396: word = 'rosemary', eeg shape = (105, 70)
# [resultsYDG_NR_pairs.mat] Index 397: word = 'clooney', eeg shape = (105, 145)
# [resultsYDG_NR_pairs.mat] Index 398: word = 'may', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 399: word = '23', eeg shape = (105, 69)
# [resultsYDG_NR_pairs.mat] Index 400: word = '1928', eeg shape = (105, 136)
# [resultsYDG_NR_pairs.mat] Index 401: word = '2002', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 402: word = 'an', eeg shape = (105, 79)
# [resultsYDG_NR_pairs.mat] Index 403: word = 'american', eeg shape = (105, 71)
# [resultsYDG_NR_pairs.mat] Index 404: word = 'popular', eeg shape = (105, 100)
# [resultsYDG_NR_pairs.mat] Index 405: word = 'singer', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 406: word = 'actress', eeg shape = (105, 93)
# [resultsYDG_NR_pairs.mat] Index 407: word = '1954', eeg shape = (105, 120)
# [resultsYDG_NR_pairs.mat] Index 408: word = 'she', eeg shape = (105, 118)
# [resultsYDG_NR_pairs.mat] Index 409: word = 'with', eeg shape = (105, 86)
# [resultsYDG_NR_pairs.mat] Index 410: word = 'bing', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 411: word = 'crosby', eeg shape = (105, 74)
# [resultsYDG_NR_pairs.mat] Index 412: word = 'danny', eeg shape = (105, 169)
# [resultsYDG_NR_pairs.mat] Index 413: word = 'kaye', eeg shape = (105, 192)
# [resultsYDG_NR_pairs.mat] Index 414: word = 'and', eeg shape = (105, 142)
# [resultsYDG_NR_pairs.mat] Index 415: word = 'veraellen', eeg shape = (105, 128)
# [resultsYDG_NR_pairs.mat] Index 416: word = 'starred', eeg shape = (105, 63)
# [resultsYDG_NR_pairs.mat] Index 417: word = 'the', eeg shape = (105, 123)
# [resultsYDG_NR_pairs.mat] Index 418: word = 'movie', eeg shape = (105, 94)
# [resultsYDG_NR_pairs.mat] Index 419: word = 'christmas', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 420: word = 'clooneys', eeg shape = (105, 74)
# [resultsYDG_NR_pairs.mat] Index 421: word = 'first', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 422: word = 'recordings', eeg shape = (105, 67)
# [resultsYDG_NR_pairs.mat] Index 423: word = 'in', eeg shape = (105, 90)
# [resultsYDG_NR_pairs.mat] Index 424: word = 'may', eeg shape = (105, 118)
# [resultsYDG_NR_pairs.mat] Index 425: word = 'of', eeg shape = (105, 87)
# [resultsYDG_NR_pairs.mat] Index 426: word = '1946', eeg shape = (105, 87)
# [resultsYDG_NR_pairs.mat] Index 427: word = 'were', eeg shape = (105, 199)
# [resultsYDG_NR_pairs.mat] Index 428: word = 'columbia', eeg shape = (105, 113)
# [resultsYDG_NR_pairs.mat] Index 429: word = 'records', eeg shape = (105, 69)
# [resultsYDG_NR_pairs.mat] Index 430: word = 'a', eeg shape = (105, 75)
# [resultsYDG_NR_pairs.mat] Index 431: word = 'singer', eeg shape = (105, 93)
# [resultsYDG_NR_pairs.mat] Index 432: word = 'with', eeg shape = (105, 127)
# [resultsYDG_NR_pairs.mat] Index 433: word = 'big', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 434: word = 'band', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 435: word = 'of', eeg shape = (105, 120)
# [resultsYDG_NR_pairs.mat] Index 436: word = 'tony', eeg shape = (105, 79)
# [resultsYDG_NR_pairs.mat] Index 437: word = 'pastor', eeg shape = (105, 134)
# [resultsYDG_NR_pairs.mat] Index 438: word = 'rosemary', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 439: word = 'clooney', eeg shape = (105, 89)
# [resultsYDG_NR_pairs.mat] Index 440: word = 'married', eeg shape = (105, 102)
# [resultsYDG_NR_pairs.mat] Index 441: word = 'times', eeg shape = (105, 86)
# [resultsYDG_NR_pairs.mat] Index 442: word = 'twice', eeg shape = (105, 74)
# [resultsYDG_NR_pairs.mat] Index 443: word = 'jose', eeg shape = (105, 122)
# [resultsYDG_NR_pairs.mat] Index 444: word = 'ferrer', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 445: word = 'from', eeg shape = (105, 107)
# [resultsYDG_NR_pairs.mat] Index 446: word = '1953', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 447: word = 'until', eeg shape = (105, 174)
# [resultsYDG_NR_pairs.mat] Index 448: word = '1961', eeg shape = (105, 164)
# [resultsYDG_NR_pairs.mat] Index 449: word = 'again', eeg shape = (105, 169)
# [resultsYDG_NR_pairs.mat] Index 450: word = 'from', eeg shape = (105, 72)
# [resultsYDG_NR_pairs.mat] Index 451: word = '1964', eeg shape = (105, 98)
# [resultsYDG_NR_pairs.mat] Index 452: word = '1967', eeg shape = (105, 63)
# [resultsYDG_NR_pairs.mat] Index 453: word = 'by', eeg shape = (105, 79)
# [resultsYDG_NR_pairs.mat] Index 454: word = 'whom', eeg shape = (105, 111)
# [resultsYDG_NR_pairs.mat] Index 455: word = 'she', eeg shape = (105, 89)
# [resultsYDG_NR_pairs.mat] Index 456: word = 'children', eeg shape = (105, 123)
# [resultsYDG_NR_pairs.mat] Index 457: word = 'including', eeg shape = (105, 142)
# [resultsYDG_NR_pairs.mat] Index 458: word = 'actor', eeg shape = (105, 60)
# [resultsYDG_NR_pairs.mat] Index 459: word = 'miguel', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 460: word = 'ferrer', eeg shape = (105, 87)
# [resultsYDG_NR_pairs.mat] Index 461: word = 'in', eeg shape = (105, 147)
# [resultsYDG_NR_pairs.mat] Index 462: word = '1955', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 463: word = 'gabriel', eeg shape = (105, 127)
# [resultsYDG_NR_pairs.mat] Index 464: word = 'ferrer', eeg shape = (105, 132)
# [resultsYDG_NR_pairs.mat] Index 465: word = 'born', eeg shape = (105, 92)
# [resultsYDG_NR_pairs.mat] Index 466: word = 'who', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 467: word = 'married', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 468: word = 'debby', eeg shape = (105, 64)
# [resultsYDG_NR_pairs.mat] Index 469: word = 'boone', eeg shape = (105, 113)
# [resultsYDG_NR_pairs.mat] Index 470: word = 'once', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 471: word = 'to', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 472: word = 'dante', eeg shape = (105, 209)
# [resultsYDG_NR_pairs.mat] Index 473: word = 'depaolo', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 474: word = 'whom', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 475: word = 'married', eeg shape = (105, 108)
# [resultsYDG_NR_pairs.mat] Index 476: word = '1997', eeg shape = (105, 90)
# [resultsYDG_NR_pairs.mat] Index 477: word = 'rosemary', eeg shape = (105, 105)
# [resultsYDG_NR_pairs.mat] Index 478: word = 'betty', eeg shape = (105, 66)
# [resultsYDG_NR_pairs.mat] Index 479: word = 'and', eeg shape = (105, 102)
# [resultsYDG_NR_pairs.mat] Index 480: word = 'brother', eeg shape = (105, 237)
# [resultsYDG_NR_pairs.mat] Index 481: word = 'nick', eeg shape = (105, 71)
# [resultsYDG_NR_pairs.mat] Index 482: word = 'well', eeg shape = (105, 83)
# [resultsYDG_NR_pairs.mat] Index 483: word = 'nephew', eeg shape = (105, 141)
# [resultsYDG_NR_pairs.mat] Index 484: word = 'george', eeg shape = (105, 116)
# [resultsYDG_NR_pairs.mat] Index 485: word = 'clooney', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 486: word = 'nicks', eeg shape = (105, 139)
# [resultsYDG_NR_pairs.mat] Index 487: word = 'son', eeg shape = (105, 132)
# [resultsYDG_NR_pairs.mat] Index 488: word = 'became', eeg shape = (105, 83)
# [resultsYDG_NR_pairs.mat] Index 489: word = 'entertainers', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 490: word = '1945', eeg shape = (105, 101)
# [resultsYDG_NR_pairs.mat] Index 491: word = 'the', eeg shape = (105, 69)
# [resultsYDG_NR_pairs.mat] Index 492: word = 'clooney', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 493: word = 'sisters', eeg shape = (105, 140)
# [resultsYDG_NR_pairs.mat] Index 494: word = 'a', eeg shape = (105, 107)
# [resultsYDG_NR_pairs.mat] Index 495: word = 'spot', eeg shape = (105, 68)
# [resultsYDG_NR_pairs.mat] Index 496: word = 'cincinnatis', eeg shape = (105, 109)
# [resultsYDG_NR_pairs.mat] Index 497: word = 'radio', eeg shape = (105, 140)
# [resultsYDG_NR_pairs.mat] Index 498: word = 'station', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 499: word = 'wlw', eeg shape = (105, 103)
# [resultsYDG_NR_pairs.mat] Index 500: word = 'as', eeg shape = (105, 88)
# [resultsYDG_NR_pairs.mat] Index 501: word = 'singers', eeg shape = (105, 81)
# [resultsYDG_NR_pairs.mat] Index 502: word = 'was', eeg shape = (105, 66)
# [resultsYDG_NR_pairs.mat] Index 503: word = 'born', eeg shape = (105, 57)
# [resultsYDG_NR_pairs.mat] Index 504: word = 'maysville', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 505: word = 'kentucky', eeg shape = (105, 125)
# [resultsYDG_NR_pairs.mat] Index 506: word = 'about', eeg shape = (105, 61)
# [resultsYDG_NR_pairs.mat] Index 507: word = '60', eeg shape = (105, 79)
# [resultsYDG_NR_pairs.mat] Index 508: word = 'miles', eeg shape = (105, 142)
# [resultsYDG_NR_pairs.mat] Index 509: word = 'ohio', eeg shape = (105, 57)
# [resultsYDG_NR_pairs.mat] Index 510: word = 'river', eeg shape = (105, 139)
# [resultsYDG_NR_pairs.mat] Index 511: word = 'from', eeg shape = (105, 161)
# [resultsYDG_NR_pairs.mat] Index 512: word = 'cincinnati', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 513: word = 'ohio', eeg shape = (105, 81)
# [resultsYDG_NR_pairs.mat] Index 514: word = 'to', eeg shape = (105, 113)
# [resultsYDG_NR_pairs.mat] Index 515: word = 'andrew', eeg shape = (105, 150)
# [resultsYDG_NR_pairs.mat] Index 516: word = 'joseph', eeg shape = (105, 58)
# [resultsYDG_NR_pairs.mat] Index 517: word = 'clooney', eeg shape = (105, 128)
# [resultsYDG_NR_pairs.mat] Index 518: word = 'and', eeg shape = (105, 102)
# [resultsYDG_NR_pairs.mat] Index 519: word = 'frances', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 520: word = 'marie', eeg shape = (105, 136)
# [resultsYDG_NR_pairs.mat] Index 521: word = 'guilfoyle', eeg shape = (105, 177)
# [resultsYDG_NR_pairs.mat] Index 522: word = 'both', eeg shape = (105, 109)
# [resultsYDG_NR_pairs.mat] Index 523: word = 'of', eeg shape = (105, 69)
# [resultsYDG_NR_pairs.mat] Index 524: word = 'whom', eeg shape = (105, 108)
# [resultsYDG_NR_pairs.mat] Index 525: word = 'descent', eeg shape = (105, 111)
# [resultsYDG_NR_pairs.mat] Index 526: word = 'nicholas', eeg shape = (105, 91)
# [resultsYDG_NR_pairs.mat] Index 527: word = 'clooney', eeg shape = (105, 64)
# [resultsYDG_NR_pairs.mat] Index 528: word = 'bridget', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 529: word = 'byron', eeg shape = (105, 132)
# [resultsYDG_NR_pairs.mat] Index 530: word = 'born', eeg shape = (105, 117)
# [resultsYDG_NR_pairs.mat] Index 531: word = 'ireland', eeg shape = (105, 145)
# [resultsYDG_NR_pairs.mat] Index 532: word = 'although', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 533: word = 'clooneys', eeg shape = (105, 121)
# [resultsYDG_NR_pairs.mat] Index 534: word = 'paternal', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 535: word = 'grandmother', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 536: word = 'crescentia', eeg shape = (105, 138)
# [resultsYDG_NR_pairs.mat] Index 537: word = 'koch', eeg shape = (105, 165)
# [resultsYDG_NR_pairs.mat] Index 538: word = 'german', eeg shape = (105, 96)
# [resultsYDG_NR_pairs.mat] Index 539: word = '1958', eeg shape = (105, 66)
# [resultsYDG_NR_pairs.mat] Index 540: word = 'clooney', eeg shape = (105, 65)
# [resultsYDG_NR_pairs.mat] Index 541: word = 'columbia', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 542: word = 'doing', eeg shape = (105, 142)
# [resultsYDG_NR_pairs.mat] Index 543: word = 'number', eeg shape = (105, 71)
# [resultsYDG_NR_pairs.mat] Index 544: word = 'recordings', eeg shape = (105, 164)
# [resultsYDG_NR_pairs.mat] Index 545: word = 'mgm', eeg shape = (105, 68)
# [resultsYDG_NR_pairs.mat] Index 546: word = 'records', eeg shape = (105, 166)
# [resultsYDG_NR_pairs.mat] Index 547: word = 'then', eeg shape = (105, 75)
# [resultsYDG_NR_pairs.mat] Index 548: word = 'some', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 549: word = 'coral', eeg shape = (105, 129)
# [resultsYDG_NR_pairs.mat] Index 550: word = 'records', eeg shape = (105, 100)
# [resultsYDG_NR_pairs.mat] Index 551: word = 'finally', eeg shape = (105, 67)
# [resultsYDG_NR_pairs.mat] Index 552: word = 'toward', eeg shape = (105, 54)
# [resultsYDG_NR_pairs.mat] Index 553: word = 'end', eeg shape = (105, 149)
# [resultsYDG_NR_pairs.mat] Index 554: word = '1958', eeg shape = (105, 119)
# [resultsYDG_NR_pairs.mat] Index 555: word = 'signed', eeg shape = (105, 211)
# [resultsYDG_NR_pairs.mat] Index 556: word = 'with', eeg shape = (105, 62)
# [resultsYDG_NR_pairs.mat] Index 557: word = 'victor', eeg shape = (105, 115)
# [resultsYDG_NR_pairs.mat] Index 558: word = 'records', eeg shape = (105, 63)
# [resultsYDG_NR_pairs.mat] Index 559: word = 'where', eeg shape = (105, 112)
# [resultsYDG_NR_pairs.mat] Index 560: word = 'stayed', eeg shape = (105, 86)
# [resultsYDG_NR_pairs.mat] Index 561: word = 'until', eeg shape = (105, 163)
# [resultsYDG_NR_pairs.mat] Index 562: word = '1963', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 563: word = 'except', eeg shape = (105, 84)
# [resultsYDG_NR_pairs.mat] Index 564: word = 'doing', eeg shape = (105, 91)
# [resultsYDG_NR_pairs.mat] Index 565: word = 'some', eeg shape = (105, 89)
# [resultsYDG_NR_pairs.mat] Index 566: word = 'recordings', eeg shape = (105, 149)
# [resultsYDG_NR_pairs.mat] Index 567: word = '1960', eeg shape = (105, 135)
# [resultsYDG_NR_pairs.mat] Index 568: word = 'for', eeg shape = (105, 121)
# [resultsYDG_NR_pairs.mat] Index 569: word = 'reprise', eeg shape = (105, 102)
# [resultsYDG_NR_pairs.mat] Index 570: word = '1964', eeg shape = (105, 81)
# [resultsYDG_NR_pairs.mat] Index 571: word = 'she', eeg shape = (105, 56)
# [resultsYDG_NR_pairs.mat] Index 572: word = 'went', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 573: word = 'reprise', eeg shape = (105, 107)
# [resultsYDG_NR_pairs.mat] Index 574: word = 'again', eeg shape = (105, 70)
# [resultsYDG_NR_pairs.mat] Index 575: word = 'shifting', eeg shape = (105, 121)
# [resultsYDG_NR_pairs.mat] Index 576: word = 'the', eeg shape = (105, 106)
# [resultsYDG_NR_pairs.mat] Index 577: word = 'next', eeg shape = (105, 87)
# [resultsYDG_NR_pairs.mat] Index 578: word = 'year', eeg shape = (105, 90)
# [resultsYDG_NR_pairs.mat] Index 579: word = 'dot', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 580: word = 'records', eeg shape = (105, 152)
# [resultsYDG_NR_pairs.mat] Index 581: word = '1966', eeg shape = (105, 161)
# [resultsYDG_NR_pairs.mat] Index 582: word = 'she', eeg shape = (105, 125)
# [resultsYDG_NR_pairs.mat] Index 583: word = 'went', eeg shape = (105, 83)
# [resultsYDG_NR_pairs.mat] Index 584: word = 'to', eeg shape = (105, 73)
# [resultsYDG_NR_pairs.mat] Index 585: word = 'united', eeg shape = (105, 90)
# [resultsYDG_NR_pairs.mat] Index 586: word = 'artists', eeg shape = (105, 96)
# [resultsYDG_NR_pairs.mat] Index 587: word = '1986', eeg shape = (105, 114)
# [resultsYDG_NR_pairs.mat] Index 588: word = 'she', eeg shape = (105, 105)
# [resultsYDG_NR_pairs.mat] Index 589: word = 'sang', eeg shape = (105, 161)
# [resultsYDG_NR_pairs.mat] Index 590: word = 'duet', eeg shape = (105, 88)
# [resultsYDG_NR_pairs.mat] Index 591: word = 'with', eeg shape = (105, 83)
# [resultsYDG_NR_pairs.mat] Index 592: word = 'wild', eeg shape = (105, 90)
# [resultsYDG_NR_pairs.mat] Index 593: word = 'man', eeg shape = (105, 98)
# [resultsYDG_NR_pairs.mat] Index 594: word = 'fischer', eeg shape = (105, 78)
# [resultsYDG_NR_pairs.mat] Index 595: word = 'its', eeg shape = (105, 99)
# [resultsYDG_NR_pairs.mat] Index 596: word = 'a', eeg shape = (105, 155)
# [resultsYDG_NR_pairs.mat] Index 597: word = 'hard', eeg shape = (105, 117)
# [resultsYDG_NR_pairs.mat] Index 598: word = 'business', eeg shape = (105, 80)
# [resultsYDG_NR_pairs.mat] Index 599: word = 'michael', eeg shape = (105, 91)
# [resultsYDG_NR_pairs.mat] Index 600: word = 'mcmanus', eeg shape = (105, 116)
# [resultsYDG_NR_pairs.mat] Index 601: word = 'february', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 602: word = 'a', eeg shape = (105, 76)
# [resultsYDG_NR_pairs.mat] Index 603: word = 'syndicated', eeg shape = (105, 132)
# [resultsYDG_NR_pairs.mat] Index 604: word = 'columnist', eeg shape = (105, 144)
# [resultsYDG_NR_pairs.mat] Index 605: word = 'wrote', eeg shape = (105, 85)
# [resultsYDG_NR_pairs.mat] Index 606: word = 'ethics', eeg shape = (105, 59)
# [resultsYDG_NR_pairs.mat] Index 607: word = 'religion', eeg shape = (105, 88)
# [resultsYDG_NR_pairs.mat] Index 608: word = 'january', eeg shape = (105, 87)
# [resultsYDG_NR_pairs.mat] Index 609: word = '28', eeg shape = (105, 96)
# [resultsYDG_NR_pairs.mat] Index 610: word = '2005', eeg shape = (105, 136)
# [resultsYDG_NR_pairs.mat] Index 611: word = 'was', eeg shape = (105, 132)
# [resultsYDG_NR_pairs.mat] Index 612: word = 'revealed', eeg shape = (105, 81)
# [resultsYDG_NR_pairs.mat] Index 613: word = 'that', eeg shape = (105, 92)
# [resultsYDG_NR_pairs.mat] Index 614: word = 'accepted', eeg shape = (105, 95)
# [resultsYDG_NR_pairs.mat] Index 615: word = 'money', eeg shape = (105, 110)
# [resultsYDG_NR_pairs.mat] Index 616: word = 'from', eeg shape = (105, 80)
# [resultsYDG_NR_pairs.mat] Index 617: word = 'the', eeg shape = (105, 111)
# [resultsYDG_NR_pairs.mat] Index 618: word = 'george', eeg shape = (105, 113)
# [resultsYDG_NR_pairs.mat] Index 619: word = 'bush', eeg shape = (105, 73)
# [resultsYDG_NR_pairs.mat] Index 620: word = 'administration', eeg shape = (105, 74)
# [resultsYDG_NR_pairs.mat] Index 621: word = 'promote', eeg shape = (105, 139)
# [resultsYDG_NR_pairs.mat] Index 622: word = 'marriage', eeg shape = (105, 132)
# [resultsYDG_NR_pairs.mat] Index 623: word = 'initiative', eeg shape = (105, 92)
# [resultsYDG_NR_pairs.mat] Index 624: word = 'program', eeg shape = (105, 72)
# [resultsYDG_NR_pairs.mat] Index 625: word = 'which', eeg shape = (105, 133)
# [resultsYDG_NR_pairs.mat] Index 626: word = 'he', eeg shape = (105, 116)
# [resultsYDG_NR_pairs.mat] Index 627: word = 'did', eeg shape = (105, 69)
# [resultsYDG_NR_pairs.mat] Index 628: word = 'disclose', eeg shape = (105, 125)
# [resultsYDG_NR_pairs.mat] Index 629: word = 'readers', eeg shape = (105, 110)
# [resultsYDG_NR_pairs.mat] Index 630: word = 'timothy', eeg shape = (105, 191)
# [resultsYDG_NR_pairs.mat] Index 631: word = 'bush', eeg shape = (105, 198)
# ...
# [resultsYSL_NR_pairs.mat] Index 5433: word = 'as', eeg shape = (105, 349)
# [resultsYSL_NR_pairs.mat] Index 5434: word = 'was', eeg shape = (105, 100)
# [resultsYSL_NR_pairs.mat] Index 5435: word = 'williard', eeg shape = (105, 185)
# [resultsYSL_NR_pairs.mat] Index 5436: word = 'fair', eeg shape = (105, 105)
# [resultsYSL_NR_pairs.mat] Index 5437: word = 'wellknown', eeg shape = (105, 199)
# [resultsYSL_NR_pairs.mat] Index 5438: word = 'local', eeg shape = (105, 352)
# [resultsYSL_NR_pairs.mat] Index 5439: word = 'black', eeg shape = (105, 133)
# [resultsYSL_NR_pairs.mat] Index 5440: word = 'activist', eeg shape = (105, 268)
# [resultsYSL_NR_pairs.mat] Index 5441: word = 'and', eeg shape = (105, 94)
# [resultsYSL_NR_pairs.mat] Index 5442: word = 'head', eeg shape = (105, 82)
# [resultsYSL_NR_pairs.mat] Index 5443: word = 'of', eeg shape = (105, 158)
# [resultsYSL_NR_pairs.mat] Index 5444: word = 'greater', eeg shape = (105, 116)
# [resultsYSL_NR_pairs.mat] Index 5445: word = 'miami', eeg shape = (105, 103)
# [resultsYSL_NR_pairs.mat] Index 5446: word = 'urban', eeg shape = (105, 239)
# [resultsYSL_NR_pairs.mat] Index 5447: word = 'league', eeg shape = (105, 219)
# [resultsYSL_NR_pairs.mat] Index 5448: word = 'governor', eeg shape = (105, 112)
# [resultsYSL_NR_pairs.mat] Index 5449: word = 'buddy', eeg shape = (105, 64)
# [resultsYSL_NR_pairs.mat] Index 5450: word = 'mackay', eeg shape = (105, 140)
# [resultsYSL_NR_pairs.mat] Index 5451: word = 'to', eeg shape = (105, 120)
# [resultsYSL_NR_pairs.mat] Index 5452: word = '45', eeg shape = (105, 120)
# [resultsYSL_NR_pairs.mat] Index 5453: word = 'become', eeg shape = (105, 145)
# [resultsYSL_NR_pairs.mat] Index 5454: word = 'governor', eeg shape = (105, 90)
# [resultsYSL_NR_pairs.mat] Index 5455: word = 'after', eeg shape = (105, 299)
# [resultsYSL_NR_pairs.mat] Index 5456: word = 'courting', eeg shape = (105, 128)
# [resultsYSL_NR_pairs.mat] Index 5457: word = 'moderate', eeg shape = (105, 148)
# [resultsYSL_NR_pairs.mat] Index 5458: word = 'voters', eeg shape = (105, 131)
# [resultsYSL_NR_pairs.mat] Index 5459: word = 'hispanics', eeg shape = (105, 84)
# [resultsYSL_NR_pairs.mat] Index 5460: word = 'he', eeg shape = (105, 136)
# [resultsYSL_NR_pairs.mat] Index 5461: word = 'then', eeg shape = (105, 82)
# [resultsYSL_NR_pairs.mat] Index 5462: word = 'enrolled', eeg shape = (105, 70)
# [resultsYSL_NR_pairs.mat] Index 5463: word = 'phillips', eeg shape = (105, 92)
# [resultsYSL_NR_pairs.mat] Index 5464: word = 'andover', eeg shape = (105, 112)
# [resultsYSL_NR_pairs.mat] Index 5465: word = 'private', eeg shape = (105, 132)
# [resultsYSL_NR_pairs.mat] Index 5466: word = 'boarding', eeg shape = (105, 92)
# [resultsYSL_NR_pairs.mat] Index 5467: word = 'school', eeg shape = (105, 133)
# [resultsYSL_NR_pairs.mat] Index 5468: word = 'massachusetts', eeg shape = (105, 128)
# [resultsYSL_NR_pairs.mat] Index 5469: word = 'already', eeg shape = (105, 103)
# [resultsYSL_NR_pairs.mat] Index 5470: word = 'attended', eeg shape = (105, 67)
# [resultsYSL_NR_pairs.mat] Index 5471: word = 'his', eeg shape = (105, 101)
# [resultsYSL_NR_pairs.mat] Index 5472: word = 'brother', eeg shape = (105, 116)
# [resultsYSL_NR_pairs.mat] Index 5473: word = 'george', eeg shape = (105, 108)
# [resultsYSL_NR_pairs.mat] Index 5474: word = 'the', eeg shape = (105, 151)
# [resultsYSL_NR_pairs.mat] Index 5475: word = 'urging', eeg shape = (105, 222)
# [resultsYSL_NR_pairs.mat] Index 5476: word = 'of', eeg shape = (105, 107)
# [resultsYSL_NR_pairs.mat] Index 5477: word = 'his', eeg shape = (105, 121)
# [resultsYSL_NR_pairs.mat] Index 5478: word = 'wife', eeg shape = (105, 99)
# [resultsYSL_NR_pairs.mat] Index 5479: word = 'columba', eeg shape = (105, 141)
# [resultsYSL_NR_pairs.mat] Index 5480: word = 'a', eeg shape = (105, 94)
# [resultsYSL_NR_pairs.mat] Index 5481: word = 'devout', eeg shape = (105, 262)
# [resultsYSL_NR_pairs.mat] Index 5482: word = 'mexican', eeg shape = (105, 91)
# [resultsYSL_NR_pairs.mat] Index 5483: word = 'catholic', eeg shape = (105, 251)
# [resultsYSL_NR_pairs.mat] Index 5484: word = 'the', eeg shape = (105, 69)
# [resultsYSL_NR_pairs.mat] Index 5485: word = 'protestant', eeg shape = (105, 102)
# [resultsYSL_NR_pairs.mat] Index 5486: word = 'bush', eeg shape = (105, 107)
# [resultsYSL_NR_pairs.mat] Index 5487: word = 'became', eeg shape = (105, 131)
# [resultsYSL_NR_pairs.mat] Index 5488: word = 'a', eeg shape = (105, 114)
# [resultsYSL_NR_pairs.mat] Index 5489: word = 'roman', eeg shape = (105, 105)
# [resultsYSL_NR_pairs.mat] Index 5490: word = 'catholic', eeg shape = (105, 116)
# [resultsYSL_NR_pairs.mat] Index 5491: word = 'bush', eeg shape = (105, 103)
# [resultsYSL_NR_pairs.mat] Index 5492: word = 'attended', eeg shape = (105, 139)
# [resultsYSL_NR_pairs.mat] Index 5493: word = 'the', eeg shape = (105, 133)
# [resultsYSL_NR_pairs.mat] Index 5494: word = 'university', eeg shape = (105, 105)
# [resultsYSL_NR_pairs.mat] Index 5495: word = 'texas', eeg shape = (105, 76)
# [resultsYSL_NR_pairs.mat] Index 5496: word = 'at', eeg shape = (105, 135)
# [resultsYSL_NR_pairs.mat] Index 5497: word = 'austin', eeg shape = (105, 208)
# [resultsYSL_NR_pairs.mat] Index 5498: word = 'where', eeg shape = (105, 126)
# [resultsYSL_NR_pairs.mat] Index 5499: word = 'graduated', eeg shape = (105, 126)
# [resultsYSL_NR_pairs.mat] Index 5500: word = 'phi', eeg shape = (105, 127)
# [resultsYSL_NR_pairs.mat] Index 5501: word = 'beta', eeg shape = (105, 114)
# [resultsYSL_NR_pairs.mat] Index 5502: word = 'kappa', eeg shape = (105, 105)
# [resultsYSL_NR_pairs.mat] Index 5503: word = 'with', eeg shape = (105, 88)
# [resultsYSL_NR_pairs.mat] Index 5504: word = 'bachelors', eeg shape = (105, 95)
# [resultsYSL_NR_pairs.mat] Index 5505: word = 'degree', eeg shape = (105, 124)
# [resultsYSL_NR_pairs.mat] Index 5506: word = 'in', eeg shape = (105, 106)
# [resultsYSL_NR_pairs.mat] Index 5507: word = 'latin', eeg shape = (105, 100)
# [resultsYSL_NR_pairs.mat] Index 5508: word = 'american', eeg shape = (105, 128)
# [resultsYSL_NR_pairs.mat] Index 5509: word = 'studies', eeg shape = (105, 107)
# [resultsYSL_NR_pairs.mat] Index 5510: word = '1973', eeg shape = (105, 103)
# [resultsYSL_NR_pairs.mat] Index 5511: word = 'taking', eeg shape = (105, 112)
# [resultsYSL_NR_pairs.mat] Index 5512: word = 'two', eeg shape = (105, 111)
# [resultsYSL_NR_pairs.mat] Index 5513: word = 'and', eeg shape = (105, 127)
# [resultsYSL_NR_pairs.mat] Index 5514: word = 'a', eeg shape = (105, 61)
# [resultsYSL_NR_pairs.mat] Index 5515: word = 'half', eeg shape = (105, 102)
# [resultsYSL_NR_pairs.mat] Index 5516: word = 'years', eeg shape = (105, 82)
# [resultsYSL_NR_pairs.mat] Index 5517: word = 'complete', eeg shape = (105, 112)
# [resultsYSL_NR_pairs.mat] Index 5518: word = 'work', eeg shape = (105, 90)
# [resultsYSL_NR_pairs.mat] Index 5519: word = 'and', eeg shape = (105, 111)
# [resultsYSL_NR_pairs.mat] Index 5520: word = 'excellent', eeg shape = (105, 77)
# [resultsYSL_NR_pairs.mat] Index 5521: word = 'grades', eeg shape = (105, 93)
# [resultsYSL_NR_pairs.mat] Index 5522: word = 'regularly', eeg shape = (105, 118)
# [resultsYSL_NR_pairs.mat] Index 5523: word = 'delivers', eeg shape = (105, 98)
# [resultsYSL_NR_pairs.mat] Index 5524: word = 'speeches', eeg shape = (105, 116)
# [resultsYSL_NR_pairs.mat] Index 5525: word = 'in', eeg shape = (105, 76)
# [resultsYSL_NR_pairs.mat] Index 5526: word = 'both', eeg shape = (105, 104)
# [resultsYSL_NR_pairs.mat] Index 5527: word = 'english', eeg shape = (105, 94)
# [resultsYSL_NR_pairs.mat] Index 5528: word = 'and', eeg shape = (105, 59)
# [resultsYSL_NR_pairs.mat] Index 5529: word = 'spanish', eeg shape = (105, 185)
# [resultsYSL_NR_pairs.mat] Index 5530: word = 'due', eeg shape = (105, 117)
# [resultsYSL_NR_pairs.mat] Index 5531: word = 'to', eeg shape = (105, 69)
# [resultsYSL_NR_pairs.mat] Index 5532: word = 'the', eeg shape = (105, 67)
# [resultsYSL_NR_pairs.mat] Index 5533: word = 'large', eeg shape = (105, 96)
# [resultsYSL_NR_pairs.mat] Index 5534: word = 'number', eeg shape = (105, 101)
# [resultsYSL_NR_pairs.mat] Index 5535: word = 'spanish', eeg shape = (105, 87)
# [resultsYSL_NR_pairs.mat] Index 5536: word = 'speaking', eeg shape = (105, 108)
# [resultsYSL_NR_pairs.mat] Index 5537: word = 'residents', eeg shape = (105, 94)
# [resultsYSL_NR_pairs.mat] Index 5538: word = 'florida', eeg shape = (105, 177)
# [resultsYSL_NR_pairs.mat] Index 5539: word = 'their', eeg shape = (105, 263)
# [resultsYSL_NR_pairs.mat] Index 5540: word = 'three', eeg shape = (105, 78)
# [resultsYSL_NR_pairs.mat] Index 5541: word = 'children', eeg shape = (105, 75)
# [resultsYSL_NR_pairs.mat] Index 5542: word = 'now', eeg shape = (105, 138)
# [resultsYSL_NR_pairs.mat] Index 5543: word = 'grown', eeg shape = (105, 88)
# [resultsYSL_NR_pairs.mat] Index 5544: word = 'are', eeg shape = (105, 117)
# [resultsYSL_NR_pairs.mat] Index 5545: word = 'george', eeg shape = (105, 98)
# [resultsYSL_NR_pairs.mat] Index 5546: word = 'p', eeg shape = (105, 55)
# [resultsYSL_NR_pairs.mat] Index 5547: word = 'recently', eeg shape = (105, 99)
# [resultsYSL_NR_pairs.mat] Index 5548: word = 'john', eeg shape = (105, 102)
# [resultsYSL_NR_pairs.mat] Index 5549: word = 'e', eeg shape = (105, 78)
# [resultsYSL_NR_pairs.mat] Index 5550: word = 'jr', eeg shape = (105, 112)
# [resultsYSL_NR_pairs.mat] Index 5551: word = 'noelle', eeg shape = (105, 52)
# [resultsYSL_NR_pairs.mat] Index 5552: word = 'november', eeg shape = (105, 187)
# [resultsYSL_NR_pairs.mat] Index 5553: word = '1977', eeg shape = (105, 139)
# [resultsYSL_NR_pairs.mat] Index 5554: word = 'he', eeg shape = (105, 103)
# [resultsYSL_NR_pairs.mat] Index 5555: word = 'was', eeg shape = (105, 105)
# [resultsYSL_NR_pairs.mat] Index 5556: word = 'sent', eeg shape = (105, 115)
# [resultsYSL_NR_pairs.mat] Index 5557: word = 'to', eeg shape = (105, 127)
# [resultsYSL_NR_pairs.mat] Index 5558: word = 'venezuelan', eeg shape = (105, 126)
# [resultsYSL_NR_pairs.mat] Index 5559: word = 'capital', eeg shape = (105, 82)
# [resultsYSL_NR_pairs.mat] Index 5560: word = 'caracas', eeg shape = (105, 69)
# [resultsYSL_NR_pairs.mat] Index 5561: word = 'in', eeg shape = (105, 164)
# [resultsYSL_NR_pairs.mat] Index 5562: word = 'south', eeg shape = (105, 87)
# [resultsYSL_NR_pairs.mat] Index 5563: word = 'america', eeg shape = (105, 143)
# [resultsYSL_NR_pairs.mat] Index 5564: word = 'to', eeg shape = (105, 101)
# [resultsYSL_NR_pairs.mat] Index 5565: word = 'open', eeg shape = (105, 75)
# [resultsYSL_NR_pairs.mat] Index 5566: word = 'a', eeg shape = (105, 119)
# [resultsYSL_NR_pairs.mat] Index 5567: word = 'operation', eeg shape = (105, 58)
# [resultsYSL_NR_pairs.mat] Index 5568: word = 'for', eeg shape = (105, 100)
# [resultsYSL_NR_pairs.mat] Index 5569: word = 'bank', eeg shape = (105, 53)
# [resultsYSL_NR_pairs.mat] Index 5570: word = 'when', eeg shape = (105, 130)
# [resultsYSL_NR_pairs.mat] Index 5571: word = 'bush', eeg shape = (105, 106)
# [resultsYSL_NR_pairs.mat] Index 5572: word = 'was', eeg shape = (105, 156)
# [resultsYSL_NR_pairs.mat] Index 5573: word = 'six', eeg shape = (105, 125)
# [resultsYSL_NR_pairs.mat] Index 5574: word = 'years', eeg shape = (105, 72)
# [resultsYSL_NR_pairs.mat] Index 5575: word = 'old', eeg shape = (105, 90)
# [resultsYSL_NR_pairs.mat] Index 5576: word = 'family', eeg shape = (105, 92)
# [resultsYSL_NR_pairs.mat] Index 5577: word = 'moved', eeg shape = (105, 85)
# [resultsYSL_NR_pairs.mat] Index 5578: word = 'houston', eeg shape = (105, 117)
# [resultsYSL_NR_pairs.mat] Index 5579: word = 'bush', eeg shape = (105, 204)
# [resultsYSL_NR_pairs.mat] Index 5580: word = 'stayed', eeg shape = (105, 112)
# [resultsYSL_NR_pairs.mat] Index 5581: word = 'houston', eeg shape = (105, 132)
# [resultsYSL_NR_pairs.mat] Index 5582: word = 'with', eeg shape = (105, 123)
# [resultsYSL_NR_pairs.mat] Index 5583: word = 'another', eeg shape = (105, 220)
# [resultsYSL_NR_pairs.mat] Index 5584: word = 'family', eeg shape = (105, 199)
# [resultsYSL_NR_pairs.mat] Index 5585: word = 'finish', eeg shape = (105, 147)
# [resultsYSL_NR_pairs.mat] Index 5586: word = 'the', eeg shape = (105, 138)
# [resultsYSL_NR_pairs.mat] Index 5587: word = 'school', eeg shape = (105, 82)
# [resultsYSL_NR_pairs.mat] Index 5588: word = 'year', eeg shape = (105, 100)
# [resultsYSL_NR_pairs.mat] Index 5589: word = 'and', eeg shape = (105, 130)
# [resultsYSL_NR_pairs.mat] Index 5590: word = 'spent', eeg shape = (105, 92)
# [resultsYSL_NR_pairs.mat] Index 5591: word = 'most', eeg shape = (105, 91)
# [resultsYSL_NR_pairs.mat] Index 5592: word = 'holidays', eeg shape = (105, 142)
# [resultsYSL_NR_pairs.mat] Index 5593: word = 'the', eeg shape = (105, 124)
# [resultsYSL_NR_pairs.mat] Index 5594: word = 'estate', eeg shape = (105, 124)
# [resultsYSL_NR_pairs.mat] Index 5595: word = 'known', eeg shape = (105, 121)
# [resultsYSL_NR_pairs.mat] Index 5596: word = 'compound', eeg shape = (105, 216)
# [resultsYSL_NR_pairs.mat] Index 5597: word = 'when', eeg shape = (105, 127)
# [resultsYSL_NR_pairs.mat] Index 5598: word = 'bush', eeg shape = (105, 109)
# [resultsYSL_NR_pairs.mat] Index 5599: word = 'was', eeg shape = (105, 70)
# [resultsYSL_NR_pairs.mat] Index 5600: word = 'seventeen', eeg shape = (105, 134)
# [resultsYSL_NR_pairs.mat] Index 5601: word = 'he', eeg shape = (105, 149)
# [resultsYSL_NR_pairs.mat] Index 5602: word = 'went', eeg shape = (105, 108)
# [resultsYSL_NR_pairs.mat] Index 5603: word = 'to', eeg shape = (105, 80)
# [resultsYSL_NR_pairs.mat] Index 5604: word = 'leon', eeg shape = (105, 78)
# [resultsYSL_NR_pairs.mat] Index 5605: word = 'mexico', eeg shape = (105, 190)
# [resultsYSL_NR_pairs.mat] Index 5606: word = 'as', eeg shape = (105, 114)
# [resultsYSL_NR_pairs.mat] Index 5607: word = 'part', eeg shape = (105, 158)
# [resultsYSL_NR_pairs.mat] Index 5608: word = 'of', eeg shape = (105, 72)
# [resultsYSL_NR_pairs.mat] Index 5609: word = 'schools', eeg shape = (105, 98)
# [resultsYSL_NR_pairs.mat] Index 5610: word = 'student', eeg shape = (105, 114)
# [resultsYSL_NR_pairs.mat] Index 5611: word = 'exchange', eeg shape = (105, 140)
# [resultsYSL_NR_pairs.mat] Index 5612: word = 'while', eeg shape = (105, 151)
# [resultsYSL_NR_pairs.mat] Index 5613: word = 'attending', eeg shape = (105, 133)
# [resultsYSL_NR_pairs.mat] Index 5614: word = 'motorcycle', eeg shape = (105, 126)
# [resultsYSL_NR_pairs.mat] Index 5615: word = 'race', eeg shape = (105, 134)
# [resultsYSL_NR_pairs.mat] Index 5616: word = 'he', eeg shape = (105, 112)
# [resultsYSL_NR_pairs.mat] Index 5617: word = 'met', eeg shape = (105, 98)
# [resultsYSL_NR_pairs.mat] Index 5618: word = 'local', eeg shape = (105, 105)
# [resultsYSL_NR_pairs.mat] Index 5619: word = 'girl', eeg shape = (105, 96)
# [resultsYSL_NR_pairs.mat] Index 5620: word = 'named', eeg shape = (105, 99)
# [resultsYSL_NR_pairs.mat] Index 5621: word = 'columba', eeg shape = (105, 162)
# [resultsYSL_NR_pairs.mat] Index 5622: word = 'garnica', eeg shape = (105, 132)
# [resultsYSL_NR_pairs.mat] Index 5623: word = 'gallo', eeg shape = (105, 112)
# [resultsYSL_NR_pairs.mat] Index 5624: word = 'whom', eeg shape = (105, 112)
# [resultsYSL_NR_pairs.mat] Index 5625: word = 'eventually', eeg shape = (105, 115)
# [resultsYSL_NR_pairs.mat] Index 5626: word = 'married', eeg shape = (105, 95)
# [resultsYSL_NR_pairs.mat] Index 5627: word = 'jeb', eeg shape = (105, 128)
# [resultsYSL_NR_pairs.mat] Index 5628: word = 'bush', eeg shape = (105, 68)
# [resultsYSL_NR_pairs.mat] Index 5629: word = 'was', eeg shape = (105, 75)
# [resultsYSL_NR_pairs.mat] Index 5630: word = 'born', eeg shape = (105, 93)
# [resultsYSL_NR_pairs.mat] Index 5631: word = 'midland', eeg shape = (105, 92)
# [resultsYSL_NR_pairs.mat] Index 5632: word = 'texas', eeg shape = (105, 146)
# [resultsYSL_NR_pairs.mat] Index 5633: word = 'where', eeg shape = (105, 125)
# [resultsYSL_NR_pairs.mat] Index 5634: word = 'father', eeg shape = (105, 75)
# [resultsYSL_NR_pairs.mat] Index 5635: word = 'was', eeg shape = (105, 85)
# [resultsYSL_NR_pairs.mat] Index 5636: word = 'running', eeg shape = (105, 103)
# [resultsYSL_NR_pairs.mat] Index 5637: word = 'an', eeg shape = (105, 183)
# [resultsYSL_NR_pairs.mat] Index 5638: word = 'oil', eeg shape = (105, 122)
# [resultsYSL_NR_pairs.mat] Index 5639: word = 'drilling', eeg shape = (105, 196)
# [resultsYSL_NR_pairs.mat] Index 5640: word = 'company', eeg shape = (105, 209)

# %%
for epoch in range(epochs):
    model.train()
    total_loss = 0
    for batch in dataloader:
        eeg = batch['eeg'].to(device)  # [B, T, C]

        pred, mask, target = model(eeg)  # unpatched prediction and mask
        loss = criterion(pred[mask], target[mask])  # MSE only on valid positions

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

    print(f"Epoch {epoch+1}, Loss: {total_loss / len(dataloader):.4f}")
# Out:
# DEBUG: <class 'numpy.ndarray'> [[-6.65174358 -3.44467972 -3.29610664 ... -4.89419179 -2.49511667
#    0.        ]
#  [-6.84282793 -4.29662349 -4.35251415 ... -7.08134374 -4.04340648
#    0.        ]
#  [-6.12566058 -4.41915931 -4.62138528 ... -8.1595117  -4.96369842
#    0.        ]
#  ...
#  [ 4.84000361  1.72805808  1.37037044 ...  2.33529039  0.97350263
#    0.        ]
#  [ 6.1125109   2.51606194  2.43877035 ...  3.65799602  1.86784093
#    0.        ]
#  [ 6.58394864  2.93179187  3.12120228 ...  4.38941356  2.43053016
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[ 4.27255724 -0.09448058  2.46623024 ... -1.65907458  2.23355492
#    0.        ]
#  [ 4.49390953  0.19575982  1.96753976 ... -1.40997045  2.25846633
#    0.        ]
#  [ 4.60232334  0.57869051  1.40556342 ... -1.00768465  2.22075121
#    0.        ]
#  ...
#  [ 4.5417187   8.25883271  8.66059866 ...  9.42580646  9.67827892
#    0.        ]
#  [ 5.46083201  9.13531942  9.14371913 ...  9.93592918 10.58251959
#    0.        ]
#  [ 6.13234051  9.46204528  9.27383117 ... 10.11978642 11.01909221
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[ 0.05840688 -1.51308196 -2.77199112 ...  0.37974116 -2.61247742
#    0.        ]
#  [-0.2108837  -2.02095962 -3.4648569  ... -0.65601639 -3.64367506
#    0.        ]
#  [-0.56184023 -2.60012727 -4.20244848 ... -1.57740933 -4.37905584
#    0.        ]
#  ...
#  [ 0.90510339  2.26354228  5.14789459 ...  2.7954287   4.81233606
#    0.        ]
#  [ 0.47641936  1.52519842  4.60081009 ...  2.21048693  4.13647111
#    0.        ]
#  [ 0.00888124  0.59106496  3.43959396 ...  1.32230478  2.91060625
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[ 0.22057759  2.18923795  4.76036074 ...  3.05546919  6.03327894
#    0.        ]
#  [ 0.0491561   2.14386202  4.87928869 ...  2.697272    5.98573555
#    0.        ]
#  [ 0.14425455  1.67787946  3.57147531 ...  1.01570713  3.42263691
#    0.        ]
#  ...
#  [-0.50627723  0.27204442  1.24248849 ...  1.73680934  2.48695097
#    0.        ]
#  [ 0.96695382  1.0530646   0.33503108 ...  1.12481005 -0.47374942
#    0.        ]
#  [ 1.92858093  1.84994391  0.4470685  ...  1.32132402 -1.33922791
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[ 3.07555081  1.78939846  0.83676354 ... -0.49318031 -0.74690832
#    0.        ]
#  [ 2.52692868  1.6520979   0.4857531  ... -0.49628906 -0.76994006
#    0.        ]
#  [ 1.7755023   1.64392323  0.3810034  ... -0.12741584 -0.60130494
#    0.        ]
#  ...
#  [-0.46538823  0.180102   -1.50468636 ... -0.40445285 -1.39463843
#    0.        ]
#  [-0.66909025  0.32511285 -1.09966455 ...  0.41609937 -0.52920382
#    0.        ]
#  [-0.87245054  0.78262742 -0.64280231 ...  1.25488276  0.16779583
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[-0.43442589 -1.89034165 -3.03651672 ... -0.63722268 -2.0531211
#    0.        ]
#  [-0.46074578 -1.67312862 -2.73351113 ... -0.45213637 -2.25257118
#    0.        ]
#  [-0.32457957 -0.5032935  -2.59048695 ... -0.23031964 -2.34047962
#    0.        ]
#  ...
#  [-3.15731376 -2.22627049 -5.9820917  ... -3.72048837 -4.8640097
#    0.        ]
#  [-3.83682263 -3.92405618 -7.11121781 ... -4.38242394 -6.25344248
#    0.        ]
#  [-4.10978066 -4.36587454 -7.47691501 ... -4.776575   -7.41054187
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[-0.46830708 -1.64918239 -4.96971501 ... -4.18796934 -2.33497026
#    0.        ]
#  [ 0.1207497  -1.16899236 -4.11197803 ... -3.5143089  -1.30549632
#    0.        ]
#  [ 0.46214978 -0.93868809 -3.17624089 ... -2.91237434 -0.47935096
#    0.        ]
#  ...
#  [ 0.28816364 -6.18608686 -9.88721622 ... -7.04906963 -7.31378419
#    0.        ]
#  [ 1.39940606 -5.61442317 -8.90019133 ... -5.4433931  -6.17537988
#    0.        ]
#  [ 2.53495391 -4.83506003 -7.5262827  ... -4.09461818 -4.67702871
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[-0.37049937  0.20605233  0.52304696 ... -0.96376863 -0.34479672
#    0.        ]
#  [-0.62937037 -0.20832823  0.17882276 ... -1.56425825 -0.76621568
#    0.        ]
#  [-0.69733527 -0.44673596 -0.19500078 ... -1.78184567 -1.03067467
#    0.        ]
#  ...
#  [-0.90974211 -0.89342958 -0.03825817 ... -0.90283433 -0.38225811
#    0.        ]
#  [-0.61382623 -0.59034306 -0.20432537 ... -0.21901605 -0.1464336
#    0.        ]
#  [ 0.13816796  0.09090265  0.08256428 ...  0.82151505  0.45211301
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[ 0.56499842  2.51537111 -2.06026604 ... -1.68310767 -1.34615019
#    0.        ]
#  [ 0.82004618  3.55207506 -1.96341844 ... -1.1972098  -0.22230766
#    0.        ]
#  [ 1.29357965  4.9425428  -0.93445652 ... -0.06212329  1.81612474
#    0.        ]
#  ...
#  [-0.50053342 -0.72236553 -5.99716847 ... -3.25708322 -3.57026346
#    0.        ]
#  [-1.11219498 -1.98992912 -6.95989175 ... -4.23488724 -4.97644941
#    0.        ]
#  [-1.63201406 -3.15580591 -7.13787029 ... -4.83937812 -5.90428125
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[ 0.70762984  1.46505344  0.8765762  ...  2.08783437  1.85510124
#    0.        ]
#  [-0.4463282   0.4132374   0.19357334 ...  0.50679106  0.55198854
#    0.        ]
#  [-1.32897927 -0.52330049 -0.47893506 ... -0.7941172  -0.56988459
#    0.        ]
#  ...
#  [-0.52836563  0.64886992  0.5179396  ... -0.64401607 -0.35594566
#    0.        ]
#  [-0.19258993  0.54089616  0.2086973  ... -0.16271682 -0.18690417
#    0.        ]
#  [ 0.03882639  0.21733566 -0.30072093 ...  0.15964267 -0.18751155
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[1.02809381 1.30184301 2.30272106 ... 1.61917434 1.95864894 0.        ]
#  [1.33018409 3.52874046 1.90078509 ... 1.46625561 1.2826195  0.        ]
#  [1.33580597 4.58043098 1.04228919 ... 1.08606002 0.4165681  0.        ]
#  ...
#  [2.33969552 7.08444334 4.64795494 ... 1.97111365 3.75508913 0.        ]
#  [2.85921012 8.41901777 4.86554671 ... 2.35504138 4.51490825 0.        ]
#  [3.17449245 9.56419458 4.70187426 ... 2.42669231 4.62970914 0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[-1.03079171  0.04016482 -3.59826593 ... -2.09033603 -4.62142777
#    0.        ]
#  [-0.81251037  1.55520118 -3.77693377 ... -2.01182967 -4.76008642
#    0.        ]
#  [-0.768839    1.59060176 -3.6448872  ... -1.75941473 -4.4831001
#    0.        ]
#  ...
#  [-0.46648201 -2.43606    -0.08366734 ...  0.36376402  1.65580807
#    0.        ]
#  [-0.29528404 -1.63748625 -0.28319362 ...  0.39367358  2.14308378
#    0.        ]
#  [ 0.23215655  0.05192252  0.02499791 ...  0.71058884  2.94258742
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[-0.48722703 -1.62666049 -0.43336982 ...  0.43881804  0.0052586
#    0.        ]
#  [-0.73492438 -2.35266205 -0.8848678  ...  0.30524952 -0.13541433
#    0.        ]
#  [-0.93825711 -2.97265917 -1.39504706 ...  0.03735055 -0.3060976
#    0.        ]
#  ...
#  [ 0.68770563  1.68770809  0.63758946 ... -0.04509967  0.28867875
#    0.        ]
#  [ 0.8528859   2.33698003  1.34040381 ...  0.4435273   0.71527749
#    0.        ]
#  [ 0.85311734  2.48044656  1.70139403 ...  0.77330557  0.93806287
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[ 2.89998125e+00  3.85100937e+00  2.81788761e+00 ...  3.12564758e+00
#    2.83573656e+00  0.00000000e+00]
#  [ 2.47479436e+00  4.94536129e+00  3.71713887e+00 ...  3.89813504e+00
#    3.52193844e+00  0.00000000e+00]
#  [ 2.09260923e+00  5.51229694e+00  4.29627506e+00 ...  4.23146630e+00
#    3.79009486e+00  0.00000000e+00]
#  ...
#  [ 3.84121159e+00  1.22867039e+00 -5.46523107e-04 ...  2.30432457e+00
#    6.32698070e-01  0.00000000e+00]
#  [ 3.67156080e+00  1.04664564e+00 -1.30498217e-01 ...  2.28453006e+00
#    8.37660507e-01  0.00000000e+00]
#  [ 2.91428265e+00  6.38275026e-01 -4.03668542e-01 ...  1.95779865e+00
#    7.52846160e-01  0.00000000e+00]]
# DEBUG: <class 'numpy.ndarray'> [[ 0.07246308  0.02743652  2.02703132 ...  3.41795456  4.46627672
#    0.        ]
#  [ 0.02857443 -0.09374365  1.94313326 ...  3.44998708  4.47938184
#    0.        ]
#  [-0.25723882 -0.45926807  0.84020833 ...  2.16571203  2.69520987
#    0.        ]
#  ...
#  [-1.42075711 -1.17166977 -1.71419839 ... -1.91784356 -2.25889746
#    0.        ]
#  [-1.14483118 -1.08389475 -0.62598697 ... -0.35979888 -0.1152868
#    0.        ]
#  [-0.76003733 -0.81050959  0.66128222 ...  1.32176425  2.1889725
#    0.        ]]
# DEBUG: <class 'numpy.ndarray'> [[-4.48157902  0.22732877  1.17695883 ... -0.72861602 -0.97703452
#    0.        ]
#  [-4.1738284   0.46155386  0.22276572 ... -1.0829138  -0.91294856
#    0.        ]
#  [-4.49610857  0.93234302 -0.44354981 ... -1.26308286 -0.78460034
#    0.        ]
#  ...
#  [ 4.08447263  0.29620938 -2.18886577 ... -3.46233712 -1.71902656
#    0.        ]
#  [ 4.32329564 -2.40382625 -4.85417796 ... -5.26771192 -4.19409514
#    0.        ]
#  [ 4.09421067 -3.92959825 -5.66502903 ... -5.55990897 -5.15711201
#    0.        ]]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[4], line 7
#       4 for batch in dataloader:
#       5     eeg = batch['eeg'].to(device)  # [B, T, C]
# ----> 7     pred, mask, target = model(eeg)  # unpatched prediction and mask
#       8     loss = criterion(pred[mask], target[mask])  # MSE only on valid positions
#      10     optimizer.zero_grad()
#
# File c:\Users\Manush\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File c:\Users\Manush\AppData\Local\Programs\Python\Python312\Lib\site-packages\torch\nn\modules\module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File c:\Users\Manush\Documents\PythonCode\BCI\eeg_pretraining\pretrainer_model.py:53, in EEGPretrainer.forward(self, x)
#      51 patch_idx = 0
#      52 for i in range(0, T - self.patch_size + 1, self.stride):
# ---> 53     unpatched_pred[:, i:i+self.patch_size] += pred_patches[:, patch_idx]
#      54     unpatched_mask[:, i:i+self.patch_size] = True
#      55     patch_idx += 1
#
# RuntimeError: The size of tensor a (25) must match the size of tensor b (16) at non-singleton dimension 1

# %%
torch.save(model.state_dict(), "eeg_pretrained.pth")
